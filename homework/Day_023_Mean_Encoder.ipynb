# %% [markdown]
# # 範例 : (Kaggle)房價預測
# ***
# - 以下用房價預測資料, 觀察均值編碼的效果

# %%
# 做完特徵工程前的所有準備
import pandas as pd
import numpy as np
import copy, time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder

data_path = 'data/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')
df_test = pd.read_csv(data_path + 'house_test.csv.gz')

train_Y = np.log1p(df_train['SalePrice'])
ids = df_test['Id']
df_train = df_train.drop(['Id', 'SalePrice'] , axis=1)
df_test = df_test.drop(['Id'] , axis=1)
df = pd.concat([df_train,df_test])
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0   NaN         NaN       0       2    2008        WD         Normal
# 1   NaN         NaN       0       5    2007        WD         Normal
# 2   NaN         NaN       0       9    2008        WD         Normal
# 3   NaN         NaN       0       2    2006        WD        Abnorml
# 4   NaN         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
#只取類別值 (object) 型欄位, 存於 object_features 中
object_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'object':
        object_features.append(feature)
print(f'{len(object_features)} Numeric Features : {object_features}\n')

# 只留類別型欄位
df = df[object_features]
df = df.fillna('None')
train_num = train_Y.shape[0]
df.head()
# Out:
# 43 Numeric Features : ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave  None      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1      ...      GarageType GarageFinish GarageQual  \
# 0      CollgCr       Norm      ...          Attchd          RFn         TA
# 1      Veenker      Feedr      ...          Attchd          RFn         TA
# 2      CollgCr       Norm      ...          Attchd          RFn         TA
# 3      Crawfor       Norm      ...          Detchd          Unf         TA
# 4      NoRidge       Norm      ...          Attchd          RFn         TA
#
#   GarageCond PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 0         TA          Y   None  None        None       WD        Normal
# 1         TA          Y   None  None        None       WD        Normal
# 2         TA          Y   None  None        None       WD        Normal
# 3         TA          Y   None  None        None       WD       Abnorml
# 4         TA          Y   None  None        None       WD        Normal
#
# [5 rows x 43 columns]

# %%
# 對照組 : 標籤編碼 + 線性迴歸
df_temp = pd.DataFrame()
for c in df.columns:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
train_X = df_temp[:train_num]
estimator = LinearRegression()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, train_X, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.6615606866851301
# time : 0.029255151748657227 sec

# %%
# 均值編碼 + 線性迴歸
data = pd.concat([df[:train_num], train_Y], axis=1)
for c in df.columns:
    mean_df = data.groupby([c])['SalePrice'].mean().reset_index()
    mean_df.columns = [c, f'{c}_mean']
    data = pd.merge(data, mean_df, on=c, how='left')
    data = data.drop([c] , axis=1)
data = data.drop(['SalePrice'] , axis=1)
estimator = LinearRegression()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, data, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
#      Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0      Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1      Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 2      Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3      Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4      Pave  None      IR1         Lvl    AllPub       FR2       Gtl
# 5      Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 6      Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 7      Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 8      Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 9      Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 10     Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 11     Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 12     Pave  None      IR2         Lvl    AllPub    Inside       Gtl
# 13     Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 14     Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 15     Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 16     Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 17     Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 18     Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 19     Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 20     Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 21     Pave  Grvl      Reg         Bnk    AllPub    Inside       Gtl
# 22     Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 23     Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 24     Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 25     Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 26     Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 27     Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 28     Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 29     Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# ...     ...   ...      ...         ...       ...       ...       ...
# 1430   Pave  None      IR3         Lvl    AllPub    Inside       Gtl
# 1431   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 1432   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 1433   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 1434   Pave  None      Reg         Low    AllPub    Inside       Mod
# 1435   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1436   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1437   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1438   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1439   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1440   Pave  None      IR1         Bnk    AllPub    Inside       Mod
# 1441   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1442   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1443   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1444   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1445   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1446   Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 1447   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1448   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1449   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1450   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 1451   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1452   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1453   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1454   Pave  Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1455   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1456   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1457   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1458   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1459   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2      ...      GarageQual GarageCond  \
# 0         CollgCr       Norm       Norm      ...              TA         TA
# 1         Veenker      Feedr       Norm      ...              TA         TA
# 2         CollgCr       Norm       Norm      ...              TA         TA
# 3         Crawfor       Norm       Norm      ...              TA         TA
# 4         NoRidge       Norm       Norm      ...              TA         TA
# 5         Mitchel       Norm       Norm      ...              TA         TA
# 6         Somerst       Norm       Norm      ...              TA         TA
# 7          NWAmes       PosN       Norm      ...              TA         TA
# 8         OldTown     Artery       Norm      ...              Fa         TA
# 9         BrkSide     Artery     Artery      ...              Gd         TA
# 10         Sawyer       Norm       Norm      ...              TA         TA
# 11        NridgHt       Norm       Norm      ...              TA         TA
# 12         Sawyer       Norm       Norm      ...              TA         TA
# 13        CollgCr       Norm       Norm      ...              TA         TA
# 14          NAmes       Norm       Norm      ...              TA         TA
# 15        BrkSide       Norm       Norm      ...              TA         TA
# 16          NAmes       Norm       Norm      ...              TA         TA
# 17         Sawyer       Norm       Norm      ...              TA         TA
# 18        SawyerW       RRAe       Norm      ...              TA         TA
# 19          NAmes       Norm       Norm      ...              TA         TA
# 20        NridgHt       Norm       Norm      ...              TA         TA
# 21         IDOTRR       Norm       Norm      ...              TA         TA
# 22        CollgCr       Norm       Norm      ...              TA         TA
# 23        MeadowV       Norm       Norm      ...              TA         TA
# 24         Sawyer       Norm       Norm      ...              TA         TA
# 25        NridgHt       Norm       Norm      ...              TA         TA
# 26          NAmes       Norm       Norm      ...              TA         TA
# 27        NridgHt       Norm       Norm      ...              TA         TA
# 28          NAmes       Norm       Norm      ...              TA         TA
# 29        BrkSide      Feedr       RRNn      ...              Fa         TA
# ...           ...        ...        ...      ...             ...        ...
# 1430      Gilbert       RRAn       Norm      ...              TA         TA
# 1431      NPkVill       Norm       Norm      ...              TA         TA
# 1432      OldTown       Norm       Norm      ...              Fa         Fa
# 1433      Gilbert       Norm       Norm      ...              TA         TA
# 1434      Mitchel       Norm       Norm      ...              TA         TA
# 1435        NAmes       Norm       Norm      ...              TA         TA
# 1436        NAmes       Norm       Norm      ...              TA         TA
# 1437      NridgHt       Norm       Norm      ...              TA         TA
# 1438      OldTown     Artery       Norm      ...              TA         TA
# 1439       NWAmes       Norm       Norm      ...              TA         TA
# 1440      Crawfor       Norm       Norm      ...              TA         TA
# 1441      CollgCr       Norm       Norm      ...              TA         TA
# 1442      Somerst       Norm       Norm      ...              TA         TA
# 1443      BrkSide       Norm       Norm      ...              Fa         Po
# 1444      CollgCr       Norm       Norm      ...              TA         TA
# 1445       Sawyer       Norm       Norm      ...              TA         TA
# 1446      Mitchel       Norm       Norm      ...              TA         TA
# 1447      CollgCr       Norm       Norm      ...              TA         TA
# 1448      Edwards       Norm       Norm      ...              Fa         TA
# 1449      MeadowV       Norm       Norm      ...            None       None
# 1450        NAmes       Norm       Norm      ...            None       None
# 1451      Somerst       Norm       Norm      ...              TA         TA
# 1452      Edwards       Norm       Norm      ...              TA         TA
# 1453      Mitchel       Norm       Norm      ...            None       None
# 1454      Somerst       Norm       Norm      ...              TA         TA
# 1455      Gilbert       Norm       Norm      ...              TA         TA
# 1456       NWAmes       Norm       Norm      ...              TA         TA
# 1457      Crawfor       Norm       Norm      ...              TA         TA
# 1458        NAmes       Norm       Norm      ...              TA         TA
# 1459      Edwards       Norm       Norm      ...              TA         TA
#
#      PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition  SalePrice  \
# 0             Y   None   None        None       WD        Normal  12.247699
# 1             Y   None   None        None       WD        Normal  12.109016
# 2             Y   None   None        None       WD        Normal  12.317171
# 3             Y   None   None        None       WD       Abnorml  11.849405
# 4             Y   None   None        None       WD        Normal  12.429220
# 5             Y   None  MnPrv        Shed       WD        Normal  11.870607
# 6             Y   None   None        None       WD        Normal  12.634606
# 7             Y   None   None        Shed       WD        Normal  12.206078
# 8             Y   None   None        None       WD       Abnorml  11.774528
# 9             Y   None   None        None       WD        Normal  11.678448
# 10            Y   None   None        None       WD        Normal  11.771444
# 11            Y   None   None        None      New       Partial  12.751303
# 12            Y   None   None        None       WD        Normal  11.877576
# 13            Y   None   None        None      New       Partial  12.540761
# 14            Y   None   GdWo        None       WD        Normal  11.964007
# 15            Y   None  GdPrv        None       WD        Normal  11.790565
# 16            Y   None   None        Shed       WD        Normal  11.911708
# 17            Y   None   None        Shed       WD        Normal  11.407576
# 18            Y   None   None        None       WD        Normal  11.976666
# 19            Y   None  MnPrv        None      COD       Abnorml  11.842236
# 20            Y   None   None        None      New       Partial  12.692506
# 21            N   None  GdPrv        None       WD        Normal  11.845110
# 22            Y   None   None        None       WD        Normal  12.345839
# 23            Y   None   None        None       WD        Normal  11.774528
# 24            Y   None  MnPrv        None       WD        Normal  11.944714
# 25            Y   None   None        None       WD        Normal  12.454108
# 26            Y   None   None        None       WD        Normal  11.811555
# 27            Y   None   None        None       WD        Normal  12.631344
# 28            Y   None   None        None       WD        Normal  12.242891
# 29            Y   None   None        None       WD        Normal  11.134604
# ...         ...    ...    ...         ...      ...           ...        ...
# 1430          Y   None   None        None       WD        Normal  12.165985
# 1431          Y   None   None        None       WD        Normal  11.875838
# 1432          Y   None   None        None       WD        Normal  11.074436
# 1433          Y   None   None        None       WD        Normal  12.136192
# 1434          P   None   None        None       WD        Normal  11.982935
# 1435          Y   None  GdPrv        None      COD       Abnorml  12.066816
# 1436          Y   None   GdWo        None       WD        Normal  11.699413
# 1437          Y   None   None        None      New       Partial  12.885673
# 1438          Y   None  MnPrv        None       WD        Normal  11.916395
# 1439          Y   None   None        None       WD        Normal  12.190964
# 1440          Y   None   None        None       WD        Normal  12.160034
# 1441          Y   None   None        None       WD        Normal  11.913720
# 1442          Y   None   None        None       WD        Normal  12.644331
# 1443          P   None   None        None       WD        Normal  11.703554
# 1444          Y   None   None        None       WD        Normal  12.098493
# 1445          Y   None   None        None       WD        Normal  11.767575
# 1446          P   None   None        None       WD        Normal  11.969724
# 1447          Y   None   None        None       WD        Normal  12.388398
# 1448          Y   None   GdWo        None       WD        Normal  11.626263
# 1449          Y   None   None        None       WD       Abnorml  11.429555
# 1450          Y   None   None        None       WD        Normal  11.820418
# 1451          Y   None   None        None      New       Partial  12.567555
# 1452          Y   None   None        None       WD        Normal  11.884496
# 1453          Y   None   None        None       WD       Abnorml  11.344519
# 1454          Y   None   None        None       WD        Normal  12.128117
# 1455          Y   None   None        None       WD        Normal  12.072547
# 1456          Y   None  MnPrv        None       WD        Normal  12.254868
# 1457          Y   None  GdPrv        Shed       WD        Normal  12.493133
# 1458          Y   None   None        None       WD        Normal  11.864469
# 1459          Y   None   None        None       WD        Normal  11.901590
#
#      MSZoning_mean
# 0        12.085891
# 1        12.085891
# 2        12.085891
# 3        12.085891
# 4        12.085891
# 5        12.085891
# 6        12.085891
# 7        12.085891
# 8        11.692901
# 9        12.085891
# 10       12.085891
# 11       12.085891
# 12       12.085891
# 13       12.085891
# 14       12.085891
# 15       11.692901
# 16       12.085891
# 17       12.085891
# 18       12.085891
# 19       12.085891
# 20       12.085891
# 21       11.692901
# 22       12.085891
# 23       11.692901
# 24       12.085891
# 25       12.085891
# 26       12.085891
# 27       12.085891
# 28       12.085891
# 29       11.692901
# ...            ...
# 1430     12.085891
# 1431     12.085891
# 1432     12.085891
# 1433     12.085891
# 1434     12.085891
# 1435     12.085891
# 1436     12.085891
# 1437     12.085891
# 1438     11.692901
# 1439     12.085891
# 1440     12.085891
# 1441     11.692901
# 1442     12.246621
# 1443     12.085891
# 1444     12.085891
# 1445     12.085891
# 1446     12.085891
# 1447     12.085891
# 1448     12.085891
# 1449     11.692901
# 1450     12.085891
# 1451     12.085891
# 1452     11.692901
# 1453     12.085891
# 1454     12.246621
# 1455     12.085891
# 1456     12.085891
# 1457     12.085891
# 1458     12.085891
# 1459     12.085891
#
# [1460 rows x 44 columns]
#      Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0     None      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1     None      Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2     None      IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3     None      IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4     None      IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# 5     None      IR1         Lvl    AllPub    Inside       Gtl      Mitchel
# 6     None      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 7     None      IR1         Lvl    AllPub    Corner       Gtl       NWAmes
# 8     None      Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 9     None      Reg         Lvl    AllPub    Corner       Gtl      BrkSide
# 10    None      Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 11    None      IR1         Lvl    AllPub    Inside       Gtl      NridgHt
# 12    None      IR2         Lvl    AllPub    Inside       Gtl       Sawyer
# 13    None      IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 14    None      IR1         Lvl    AllPub    Corner       Gtl        NAmes
# 15    None      Reg         Lvl    AllPub    Corner       Gtl      BrkSide
# 16    None      IR1         Lvl    AllPub   CulDSac       Gtl        NAmes
# 17    None      Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 18    None      Reg         Lvl    AllPub    Inside       Gtl      SawyerW
# 19    None      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 20    None      IR1         Lvl    AllPub    Corner       Gtl      NridgHt
# 21    Grvl      Reg         Bnk    AllPub    Inside       Gtl       IDOTRR
# 22    None      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 23    None      Reg         Lvl    AllPub    Inside       Gtl      MeadowV
# 24    None      IR1         Lvl    AllPub    Inside       Gtl       Sawyer
# 25    None      Reg         Lvl    AllPub    Corner       Gtl      NridgHt
# 26    None      Reg         Lvl    AllPub    Corner       Gtl        NAmes
# 27    None      Reg         Lvl    AllPub    Inside       Gtl      NridgHt
# 28    None      IR1         Lvl    AllPub   CulDSac       Gtl        NAmes
# 29    None      IR1         Lvl    AllPub    Inside       Gtl      BrkSide
# ...    ...      ...         ...       ...       ...       ...          ...
# 1430  None      IR3         Lvl    AllPub    Inside       Gtl      Gilbert
# 1431  None      IR1         Lvl    AllPub    Inside       Gtl      NPkVill
# 1432  Grvl      Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 1433  None      IR1         Lvl    AllPub    Inside       Gtl      Gilbert
# 1434  None      Reg         Low    AllPub    Inside       Mod      Mitchel
# 1435  None      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1436  None      Reg         Lvl    AllPub       FR2       Gtl        NAmes
# 1437  None      Reg         Lvl    AllPub       FR2       Gtl      NridgHt
# 1438  None      Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 1439  None      Reg         Lvl    AllPub    Inside       Gtl       NWAmes
# 1440  None      IR1         Bnk    AllPub    Inside       Mod      Crawfor
# 1441  None      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1442  None      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 1443  None      Reg         Lvl    AllPub    Inside       Gtl      BrkSide
# 1444  None      Reg         Lvl    AllPub       FR2       Gtl      CollgCr
# 1445  None      Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 1446  None      IR1         Lvl    AllPub   CulDSac       Gtl      Mitchel
# 1447  None      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1448  None      Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 1449  None      Reg         Lvl    AllPub    Inside       Gtl      MeadowV
# 1450  None      Reg         Lvl    AllPub       FR2       Gtl        NAmes
# 1451  None      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 1452  None      Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 1453  None      Reg         Lvl    AllPub    Inside       Gtl      Mitchel
# 1454  Pave      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 1455  None      Reg         Lvl    AllPub    Inside       Gtl      Gilbert
# 1456  None      Reg         Lvl    AllPub    Inside       Gtl       NWAmes
# 1457  None      Reg         Lvl    AllPub    Inside       Gtl      Crawfor
# 1458  None      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1459  None      Reg         Lvl    AllPub    Inside       Gtl      Edwards
#
#      Condition1 Condition2 BldgType     ...     GarageCond PavedDrive PoolQC  \
# 0          Norm       Norm     1Fam     ...             TA          Y   None
# 1         Feedr       Norm     1Fam     ...             TA          Y   None
# 2          Norm       Norm     1Fam     ...             TA          Y   None
# 3          Norm       Norm     1Fam     ...             TA          Y   None
# 4          Norm       Norm     1Fam     ...             TA          Y   None
# 5          Norm       Norm     1Fam     ...             TA          Y   None
# 6          Norm       Norm     1Fam     ...             TA          Y   None
# 7          PosN       Norm     1Fam     ...             TA          Y   None
# 8        Artery       Norm     1Fam     ...             TA          Y   None
# 9        Artery     Artery   2fmCon     ...             TA          Y   None
# 10         Norm       Norm     1Fam     ...             TA          Y   None
# 11         Norm       Norm     1Fam     ...             TA          Y   None
# 12         Norm       Norm     1Fam     ...             TA          Y   None
# 13         Norm       Norm     1Fam     ...             TA          Y   None
# 14         Norm       Norm     1Fam     ...             TA          Y   None
# 15         Norm       Norm     1Fam     ...             TA          Y   None
# 16         Norm       Norm     1Fam     ...             TA          Y   None
# 17         Norm       Norm   Duplex     ...             TA          Y   None
# 18         RRAe       Norm     1Fam     ...             TA          Y   None
# 19         Norm       Norm     1Fam     ...             TA          Y   None
# 20         Norm       Norm     1Fam     ...             TA          Y   None
# 21         Norm       Norm     1Fam     ...             TA          N   None
# 22         Norm       Norm     1Fam     ...             TA          Y   None
# 23         Norm       Norm   TwnhsE     ...             TA          Y   None
# 24         Norm       Norm     1Fam     ...             TA          Y   None
# 25         Norm       Norm     1Fam     ...             TA          Y   None
# 26         Norm       Norm     1Fam     ...             TA          Y   None
# 27         Norm       Norm     1Fam     ...             TA          Y   None
# 28         Norm       Norm     1Fam     ...             TA          Y   None
# 29        Feedr       RRNn     1Fam     ...             TA          Y   None
# ...         ...        ...      ...     ...            ...        ...    ...
# 1430       RRAn       Norm     1Fam     ...             TA          Y   None
# 1431       Norm       Norm   TwnhsE     ...             TA          Y   None
# 1432       Norm       Norm     1Fam     ...             Fa          Y   None
# 1433       Norm       Norm     1Fam     ...             TA          Y   None
# 1434       Norm       Norm     1Fam     ...             TA          P   None
# 1435       Norm       Norm     1Fam     ...             TA          Y   None
# 1436       Norm       Norm     1Fam     ...             TA          Y   None
# 1437       Norm       Norm     1Fam     ...             TA          Y   None
# 1438     Artery       Norm     1Fam     ...             TA          Y   None
# 1439       Norm       Norm     1Fam     ...             TA          Y   None
# 1440       Norm       Norm     1Fam     ...             TA          Y   None
# 1441       Norm       Norm   TwnhsE     ...             TA          Y   None
# 1442       Norm       Norm     1Fam     ...             TA          Y   None
# 1443       Norm       Norm     1Fam     ...             Po          P   None
# 1444       Norm       Norm     1Fam     ...             TA          Y   None
# 1445       Norm       Norm     1Fam     ...             TA          Y   None
# 1446       Norm       Norm     1Fam     ...             TA          P   None
# 1447       Norm       Norm     1Fam     ...             TA          Y   None
# 1448       Norm       Norm     1Fam     ...             TA          Y   None
# 1449       Norm       Norm    Twnhs     ...           None          Y   None
# 1450       Norm       Norm   Duplex     ...           None          Y   None
# 1451       Norm       Norm     1Fam     ...             TA          Y   None
# 1452       Norm       Norm   TwnhsE     ...             TA          Y   None
# 1453       Norm       Norm     1Fam     ...           None          Y   None
# 1454       Norm       Norm     1Fam     ...             TA          Y   None
# 1455       Norm       Norm     1Fam     ...             TA          Y   None
# 1456       Norm       Norm     1Fam     ...             TA          Y   None
# 1457       Norm       Norm     1Fam     ...             TA          Y   None
# 1458       Norm       Norm     1Fam     ...             TA          Y   None
# 1459       Norm       Norm     1Fam     ...             TA          Y   None
#
#       Fence MiscFeature SaleType SaleCondition  SalePrice MSZoning_mean  \
# 0      None        None       WD        Normal  12.247699     12.085891
# 1      None        None       WD        Normal  12.109016     12.085891
# 2      None        None       WD        Normal  12.317171     12.085891
# 3      None        None       WD       Abnorml  11.849405     12.085891
# 4      None        None       WD        Normal  12.429220     12.085891
# 5     MnPrv        Shed       WD        Normal  11.870607     12.085891
# 6      None        None       WD        Normal  12.634606     12.085891
# 7      None        Shed       WD        Normal  12.206078     12.085891
# 8      None        None       WD       Abnorml  11.774528     11.692901
# 9      None        None       WD        Normal  11.678448     12.085891
# 10     None        None       WD        Normal  11.771444     12.085891
# 11     None        None      New       Partial  12.751303     12.085891
# 12     None        None       WD        Normal  11.877576     12.085891
# 13     None        None      New       Partial  12.540761     12.085891
# 14     GdWo        None       WD        Normal  11.964007     12.085891
# 15    GdPrv        None       WD        Normal  11.790565     11.692901
# 16     None        Shed       WD        Normal  11.911708     12.085891
# 17     None        Shed       WD        Normal  11.407576     12.085891
# 18     None        None       WD        Normal  11.976666     12.085891
# 19    MnPrv        None      COD       Abnorml  11.842236     12.085891
# 20     None        None      New       Partial  12.692506     12.085891
# 21    GdPrv        None       WD        Normal  11.845110     11.692901
# 22     None        None       WD        Normal  12.345839     12.085891
# 23     None        None       WD        Normal  11.774528     11.692901
# 24    MnPrv        None       WD        Normal  11.944714     12.085891
# 25     None        None       WD        Normal  12.454108     12.085891
# 26     None        None       WD        Normal  11.811555     12.085891
# 27     None        None       WD        Normal  12.631344     12.085891
# 28     None        None       WD        Normal  12.242891     12.085891
# 29     None        None       WD        Normal  11.134604     11.692901
# ...     ...         ...      ...           ...        ...           ...
# 1430   None        None       WD        Normal  12.165985     12.085891
# 1431   None        None       WD        Normal  11.875838     12.085891
# 1432   None        None       WD        Normal  11.074436     12.085891
# 1433   None        None       WD        Normal  12.136192     12.085891
# 1434   None        None       WD        Normal  11.982935     12.085891
# 1435  GdPrv        None      COD       Abnorml  12.066816     12.085891
# 1436   GdWo        None       WD        Normal  11.699413     12.085891
# 1437   None        None      New       Partial  12.885673     12.085891
# 1438  MnPrv        None       WD        Normal  11.916395     11.692901
# 1439   None        None       WD        Normal  12.190964     12.085891
# 1440   None        None       WD        Normal  12.160034     12.085891
# 1441   None        None       WD        Normal  11.913720     11.692901
# 1442   None        None       WD        Normal  12.644331     12.246621
# 1443   None        None       WD        Normal  11.703554     12.085891
# 1444   None        None       WD        Normal  12.098493     12.085891
# 1445   None        None       WD        Normal  11.767575     12.085891
# 1446   None        None       WD        Normal  11.969724     12.085891
# 1447   None        None       WD        Normal  12.388398     12.085891
# 1448   GdWo        None       WD        Normal  11.626263     12.085891
# 1449   None        None       WD       Abnorml  11.429555     11.692901
# 1450   None        None       WD        Normal  11.820418     12.085891
# 1451   None        None      New       Partial  12.567555     12.085891
# 1452   None        None       WD        Normal  11.884496     11.692901
# 1453   None        None       WD       Abnorml  11.344519     12.085891
# 1454   None        None       WD        Normal  12.128117     12.246621
# 1455   None        None       WD        Normal  12.072547     12.085891
# 1456  MnPrv        None       WD        Normal  12.254868     12.085891
# 1457  GdPrv        Shed       WD        Normal  12.493133     12.085891
# 1458   None        None       WD        Normal  11.864469     12.085891
# 1459   None        None       WD        Normal  11.901590     12.085891
#
#      Street_mean
# 0      12.025529
# 1      12.025529
# 2      12.025529
# 3      12.025529
# 4      12.025529
# 5      12.025529
# 6      12.025529
# 7      12.025529
# 8      12.025529
# 9      12.025529
# 10     12.025529
# 11     12.025529
# 12     12.025529
# 13     12.025529
# 14     12.025529
# 15     12.025529
# 16     12.025529
# 17     12.025529
# 18     12.025529
# 19     12.025529
# 20     12.025529
# 21     12.025529
# 22     12.025529
# 23     12.025529
# 24     12.025529
# 25     12.025529
# 26     12.025529
# 27     12.025529
# 28     12.025529
# 29     12.025529
# ...          ...
# 1430   12.025529
# 1431   12.025529
# 1432   12.025529
# 1433   12.025529
# 1434   12.025529
# 1435   12.025529
# 1436   12.025529
# 1437   12.025529
# 1438   12.025529
# 1439   12.025529
# 1440   12.025529
# 1441   12.025529
# 1442   12.025529
# 1443   12.025529
# 1444   12.025529
# 1445   12.025529
# 1446   12.025529
# 1447   12.025529
# 1448   12.025529
# 1449   12.025529
# 1450   12.025529
# 1451   12.025529
# 1452   12.025529
# 1453   12.025529
# 1454   12.025529
# 1455   12.025529
# 1456   12.025529
# 1457   12.025529
# 1458   12.025529
# 1459   12.025529
#
# [1460 rows x 44 columns]
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0         Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1         Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2         IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3         IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4         IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# 5         IR1         Lvl    AllPub    Inside       Gtl      Mitchel
# 6         Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 7         IR1         Lvl    AllPub    Corner       Gtl       NWAmes
# 8         Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 9         Reg         Lvl    AllPub    Corner       Gtl      BrkSide
# 10        Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 11        IR1         Lvl    AllPub    Inside       Gtl      NridgHt
# 12        IR2         Lvl    AllPub    Inside       Gtl       Sawyer
# 13        IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 14        IR1         Lvl    AllPub    Corner       Gtl        NAmes
# 15        Reg         Lvl    AllPub    Corner       Gtl      BrkSide
# 16        IR1         Lvl    AllPub   CulDSac       Gtl        NAmes
# 17        Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 18        Reg         Lvl    AllPub    Inside       Gtl      SawyerW
# 19        Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 20        IR1         Lvl    AllPub    Corner       Gtl      NridgHt
# 21        Reg         Bnk    AllPub    Inside       Gtl       IDOTRR
# 22        Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 23        Reg         Lvl    AllPub    Inside       Gtl      MeadowV
# 24        IR1         Lvl    AllPub    Inside       Gtl       Sawyer
# 25        Reg         Lvl    AllPub    Corner       Gtl      NridgHt
# 26        Reg         Lvl    AllPub    Corner       Gtl        NAmes
# 27        Reg         Lvl    AllPub    Inside       Gtl      NridgHt
# 28        IR1         Lvl    AllPub   CulDSac       Gtl        NAmes
# 29        IR1         Lvl    AllPub    Inside       Gtl      BrkSide
# ...       ...         ...       ...       ...       ...          ...
# 1430      IR3         Lvl    AllPub    Inside       Gtl      Gilbert
# 1431      IR1         Lvl    AllPub    Inside       Gtl      NPkVill
# 1432      Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 1433      IR1         Lvl    AllPub    Inside       Gtl      Gilbert
# 1434      Reg         Low    AllPub    Inside       Mod      Mitchel
# 1435      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1436      Reg         Lvl    AllPub       FR2       Gtl        NAmes
# 1437      Reg         Lvl    AllPub       FR2       Gtl      NridgHt
# 1438      Reg         Lvl    AllPub    Inside       Gtl      OldTown
# 1439      Reg         Lvl    AllPub    Inside       Gtl       NWAmes
# 1440      IR1         Bnk    AllPub    Inside       Mod      Crawfor
# 1441      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1442      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 1443      Reg         Lvl    AllPub    Inside       Gtl      BrkSide
# 1444      Reg         Lvl    AllPub       FR2       Gtl      CollgCr
# 1445      Reg         Lvl    AllPub    Inside       Gtl       Sawyer
# 1446      IR1         Lvl    AllPub   CulDSac       Gtl      Mitchel
# 1447      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1448      Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 1449      Reg         Lvl    AllPub    Inside       Gtl      MeadowV
# 1450      Reg         Lvl    AllPub       FR2       Gtl        NAmes
# 1451      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 1452      Reg         Lvl    AllPub    Inside       Gtl      Edwards
# 1453      Reg         Lvl    AllPub    Inside       Gtl      Mitchel
# 1454      Reg         Lvl    AllPub    Inside       Gtl      Somerst
# 1455      Reg         Lvl    AllPub    Inside       Gtl      Gilbert
# 1456      Reg         Lvl    AllPub    Inside       Gtl       NWAmes
# 1457      Reg         Lvl    AllPub    Inside       Gtl      Crawfor
# 1458      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1459      Reg         Lvl    AllPub    Inside       Gtl      Edwards
#
#      Condition1 Condition2 BldgType HouseStyle    ...     PavedDrive PoolQC  \
# 0          Norm       Norm     1Fam     2Story    ...              Y   None
# 1         Feedr       Norm     1Fam     1Story    ...              Y   None
# 2          Norm       Norm     1Fam     2Story    ...              Y   None
# 3          Norm       Norm     1Fam     2Story    ...              Y   None
# 4          Norm       Norm     1Fam     2Story    ...              Y   None
# 5          Norm       Norm     1Fam     1.5Fin    ...              Y   None
# 6          Norm       Norm     1Fam     1Story    ...              Y   None
# 7          PosN       Norm     1Fam     2Story    ...              Y   None
# 8        Artery       Norm     1Fam     1.5Fin    ...              Y   None
# 9        Artery     Artery   2fmCon     1.5Unf    ...              Y   None
# 10         Norm       Norm     1Fam     1Story    ...              Y   None
# 11         Norm       Norm     1Fam     2Story    ...              Y   None
# 12         Norm       Norm     1Fam     1Story    ...              Y   None
# 13         Norm       Norm     1Fam     1Story    ...              Y   None
# 14         Norm       Norm     1Fam     1Story    ...              Y   None
# 15         Norm       Norm     1Fam     1.5Unf    ...              Y   None
# 16         Norm       Norm     1Fam     1Story    ...              Y   None
# 17         Norm       Norm   Duplex     1Story    ...              Y   None
# 18         RRAe       Norm     1Fam     1Story    ...              Y   None
# 19         Norm       Norm     1Fam     1Story    ...              Y   None
# 20         Norm       Norm     1Fam     2Story    ...              Y   None
# 21         Norm       Norm     1Fam     1.5Unf    ...              N   None
# 22         Norm       Norm     1Fam     1Story    ...              Y   None
# 23         Norm       Norm   TwnhsE     1Story    ...              Y   None
# 24         Norm       Norm     1Fam     1Story    ...              Y   None
# 25         Norm       Norm     1Fam     1Story    ...              Y   None
# 26         Norm       Norm     1Fam     1Story    ...              Y   None
# 27         Norm       Norm     1Fam     1Story    ...              Y   None
# 28         Norm       Norm     1Fam     1Story    ...              Y   None
# 29        Feedr       RRNn     1Fam     1Story    ...              Y   None
# ...         ...        ...      ...        ...    ...            ...    ...
# 1430       RRAn       Norm     1Fam     2Story    ...              Y   None
# 1431       Norm       Norm   TwnhsE     1Story    ...              Y   None
# 1432       Norm       Norm     1Fam     1Story    ...              Y   None
# 1433       Norm       Norm     1Fam     2Story    ...              Y   None
# 1434       Norm       Norm     1Fam     1Story    ...              P   None
# 1435       Norm       Norm     1Fam     1Story    ...              Y   None
# 1436       Norm       Norm     1Fam     1Story    ...              Y   None
# 1437       Norm       Norm     1Fam     1Story    ...              Y   None
# 1438     Artery       Norm     1Fam     1Story    ...              Y   None
# 1439       Norm       Norm     1Fam       SLvl    ...              Y   None
# 1440       Norm       Norm     1Fam     2.5Fin    ...              Y   None
# 1441       Norm       Norm   TwnhsE     1Story    ...              Y   None
# 1442       Norm       Norm     1Fam     2Story    ...              Y   None
# 1443       Norm       Norm     1Fam     1.5Unf    ...              P   None
# 1444       Norm       Norm     1Fam     1Story    ...              Y   None
# 1445       Norm       Norm     1Fam     SFoyer    ...              Y   None
# 1446       Norm       Norm     1Fam     1Story    ...              P   None
# 1447       Norm       Norm     1Fam     2Story    ...              Y   None
# 1448       Norm       Norm     1Fam     2Story    ...              Y   None
# 1449       Norm       Norm    Twnhs     SFoyer    ...              Y   None
# 1450       Norm       Norm   Duplex     2Story    ...              Y   None
# 1451       Norm       Norm     1Fam     1Story    ...              Y   None
# 1452       Norm       Norm   TwnhsE       SLvl    ...              Y   None
# 1453       Norm       Norm     1Fam     1Story    ...              Y   None
# 1454       Norm       Norm     1Fam     1Story    ...              Y   None
# 1455       Norm       Norm     1Fam     2Story    ...              Y   None
# 1456       Norm       Norm     1Fam     1Story    ...              Y   None
# 1457       Norm       Norm     1Fam     2Story    ...              Y   None
# 1458       Norm       Norm     1Fam     1Story    ...              Y   None
# 1459       Norm       Norm     1Fam     1Story    ...              Y   None
#
#       Fence MiscFeature SaleType SaleCondition  SalePrice MSZoning_mean  \
# 0      None        None       WD        Normal  12.247699     12.085891
# 1      None        None       WD        Normal  12.109016     12.085891
# 2      None        None       WD        Normal  12.317171     12.085891
# 3      None        None       WD       Abnorml  11.849405     12.085891
# 4      None        None       WD        Normal  12.429220     12.085891
# 5     MnPrv        Shed       WD        Normal  11.870607     12.085891
# 6      None        None       WD        Normal  12.634606     12.085891
# 7      None        Shed       WD        Normal  12.206078     12.085891
# 8      None        None       WD       Abnorml  11.774528     11.692901
# 9      None        None       WD        Normal  11.678448     12.085891
# 10     None        None       WD        Normal  11.771444     12.085891
# 11     None        None      New       Partial  12.751303     12.085891
# 12     None        None       WD        Normal  11.877576     12.085891
# 13     None        None      New       Partial  12.540761     12.085891
# 14     GdWo        None       WD        Normal  11.964007     12.085891
# 15    GdPrv        None       WD        Normal  11.790565     11.692901
# 16     None        Shed       WD        Normal  11.911708     12.085891
# 17     None        Shed       WD        Normal  11.407576     12.085891
# 18     None        None       WD        Normal  11.976666     12.085891
# 19    MnPrv        None      COD       Abnorml  11.842236     12.085891
# 20     None        None      New       Partial  12.692506     12.085891
# 21    GdPrv        None       WD        Normal  11.845110     11.692901
# 22     None        None       WD        Normal  12.345839     12.085891
# 23     None        None       WD        Normal  11.774528     11.692901
# 24    MnPrv        None       WD        Normal  11.944714     12.085891
# 25     None        None       WD        Normal  12.454108     12.085891
# 26     None        None       WD        Normal  11.811555     12.085891
# 27     None        None       WD        Normal  12.631344     12.085891
# 28     None        None       WD        Normal  12.242891     12.085891
# 29     None        None       WD        Normal  11.134604     11.692901
# ...     ...         ...      ...           ...        ...           ...
# 1430   None        None       WD        Normal  12.165985     12.085891
# 1431   None        None       WD        Normal  11.875838     12.085891
# 1432   None        None       WD        Normal  11.074436     12.085891
# 1433   None        None       WD        Normal  12.136192     12.085891
# 1434   None        None       WD        Normal  11.982935     12.085891
# 1435  GdPrv        None      COD       Abnorml  12.066816     12.085891
# 1436   GdWo        None       WD        Normal  11.699413     12.085891
# 1437   None        None      New       Partial  12.885673     12.085891
# 1453    12.022122   12.058605         12.030119      11.991068
# 1454    12.022122   12.058605         12.030119      11.991068
# 1455    12.022122   12.058605         12.030119      11.991068
# 1456    12.022122   11.850604         12.030119      11.991068
# 1457    12.022122   12.057119         11.868394      11.991068
# 1458    12.022122   12.058605         12.030119      11.991068
# 1459    12.022122   12.058605         12.030119      11.991068
#
#       SaleCondition_mean
# 0              12.005040
# 1              12.005040
# 2              12.005040
# 3              11.788783
# 4              12.005040
# 5              12.005040
# 6              12.005040
# 7              12.005040
# 8              11.788783
# 9              12.005040
# 10             12.005040
# 11             12.447481
# 12             12.005040
# 13             12.447481
# 14             12.005040
# 15             12.005040
# 16             12.005040
# 17             12.005040
# 18             12.005040
# 19             11.788783
# 20             12.447481
# 21             12.005040
# 22             12.005040
# 23             12.005040
# 24             12.005040
# 25             12.005040
# 26             12.005040
# 27             12.005040
# 28             12.005040
# 29             12.005040
# ...                  ...
# 1430           12.005040
# 1431           12.005040
# 1432           12.005040
# 1433           12.005040
# 1434           12.005040
# 1435           11.788783
# 1436           12.005040
# 1437           12.447481
# 1438           12.005040
# 1439           12.005040
# 1440           12.005040
# 1441           12.005040
# 1442           12.005040
# 1443           12.005040
# 1444           12.005040
# 1445           12.005040
# 1446           12.005040
# 1447           12.005040
# 1448           12.005040
# 1449           11.788783
# 1450           12.005040
# 1451           12.447481
# 1452           12.005040
# 1453           11.788783
# 1454           12.005040
# 1455           12.005040
# 1456           12.005040
# 1457           12.005040
# 1458           12.005040
# 1459           12.005040
#
# [1460 rows x 44 columns]
# shape : (1460, 43)
# score : 0.7624230403716953
# time : 0.014966011047363281 sec

# %%
# 對照組 : 標籤編碼 + 梯度提升樹
df_temp = pd.DataFrame()
for c in df.columns:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
train_X = df_temp[:train_num]
estimator = GradientBoostingRegressor()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, train_X, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.7783758280436521
# time : 0.5922949314117432 sec

# %%
# 均值編碼 + 梯度提升樹
data = pd.concat([df[:train_num], train_Y], axis=1)
for c in df.columns:
    mean_df = data.groupby([c])['SalePrice'].mean().reset_index()
    mean_df.columns = [c, f'{c}_mean']
    data = pd.merge(data, mean_df, on=c, how='left')
    data = data.drop([c] , axis=1)
data = data.drop(['SalePrice'] , axis=1)
estimator = GradientBoostingRegressor()
start = time.time()
print(f'shape : {train_X.shape}')
print(f'score : {cross_val_score(estimator, data, train_Y, cv=5).mean()}')
print(f'time : {time.time() - start} sec')
# Out:
# shape : (1460, 43)
# score : 0.8064165648022528
# time : 0.5679852962493896 sec

# %% [markdown]
# # 作業1
# * 請仿照範例，將鐵達尼範例中的類別型特徵改用均值編碼實作一次
#
# # 作業2
# * 觀察鐵達尼生存預測中，均值編碼與標籤編碼兩者比較，哪一個效果比較好? 可能的原因是什麼?
